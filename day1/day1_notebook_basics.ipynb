# %% [markdown]
# ## Getting started with notebook

# %%
print ("hello python")

# %%
# %sql
select "hello sql"

# %% [markdown]
# ## Creating Schema

# %%
# %sql
use catalog ak_dev;
create schema ak_dev.example;

# %%
# %sql
create schema ak_dev.example

# %%
# %sql
create schema if not exists ak_dev.example

# %%
# %sql
create table ak_dev.example.emp (id int primary key, name string)

# %%
# %sql
insert into ak_dev.example.emp values (1,'Naval'),(2,'Anil'),(3,'Sangram')
