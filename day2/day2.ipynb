# %%
ELT/ETL

Way to create a table

1. sql
2. pyspark
3.UI

# %%
1. spark sql
2. read files : select * from read files ("path",format =>"format")
3. query : select * from file_format.`path`

# %%
# %sql
select * from read_files("/Volumes/ak_dev/default/csv_files")

# %%
# %sql
create table ak_dev.default.financial as
select * from read_files("/Volumes/ak_dev/default/csv_files/financial_dataset.csv")

# %%
# %sql

# %%
# %sql
describe ak_dev.default.financial

# %%
# %sql
describe history ak_dev.default.financial

# %%
# %sql
describe extended ak_dev.default.financial
