# %%
df_finace=spark.read.csv("/Volumes/ak_dev/default/csv_files/financial.csv")

# %%
df_finace=spark.read.csv("/Volumes/ak_dev/default/csv_files/financial_dataset.csv",header=True,inferSchema=True)

# %%
df_deposit=df_finace.filter("TransactionType='Deposit'")

# %%
# Lazy evalution:
#     Transformation
#         1. read
#         2. Filter
 
 
#     Action.
#         1.show or display
#         2.count
#         3.write

# %%
/Volumes/ak_dev/default/csv_files/financial_dataset.csv

# %%
df_deposit.count()

# %%
df_finace.write.saveAsTable("ak_dev.default.finance_pyspark")

# %%
df_finace=spark.read.csv("/Volumes/ak_dev/default/csv_files/financial_dataset.csv",header=True,inferSchema=True)

# %%
/Volumes/ak_dev/default/csv_files/financial_dataset.csv

# %%
df_finace.write.mode("overwrite").saveAsTable("ak_dev.default.finance_pyspark")
